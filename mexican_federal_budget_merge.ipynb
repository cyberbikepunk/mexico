# %% [markdown]
# # Merge the Mexican Federal Budget files

# %%
from sys import stdout

# %% [markdown]
# ## Data ingestion
#
# Ingest all columns as raw strings.

# %%
def read_columns(file):
    with open(file, encoding='iso-8859-1') as csv:
        header = csv.readline()
        return header.replace('\n', '').split(',')

# %%
def force_strings(columns):
    for column in columns:
        yield column, str

# %%
import cchardet as chardet

def detect_encoding(years, file_format):
    for year in years:
        filename = file_format % year

        with open(filename, 'rb') as f:
            text = f.read()
            
        result = chardet.detect(text)
        print('Inspecting', filename, result)

# %%
from pandas import read_csv

def load_csv_files(years, file_format, encoding_):
    df = {}
    
    for year in years:
        filename = file_format % year
        columns = read_columns(filename)
        types = dict(force_strings(columns))
        
        print('Loading', filename, 'with encoding:', encoding_)
        stdout.flush()
        
        df[year] = read_csv(filename, encoding=encoding_, dtype=types)
    
    return df

# %% [markdown]
# ## Column mapping

# %%
from sys import stdout

def strip_blanks(batch):
    for year in batch.keys():
        for column in batch[year].columns:
            batch[year].rename(columns={column: column.strip()}, inplace=True)
            if column.strip() != column:
                print(year, column, 'stripped blanks')
                stdout.flush()

# %%
def delete_empty_columns(batch):
    for year in batch.keys():
        for column in batch[year].columns:
            if 'Unnamed:' in column:
                try:
                    del batch[year][column]
                    print(year, column, 'deleted')
                    stdout.flush()
                except KeyError:
                    pass

# %%
def get_union_of_columns(batch):
    union = set()
    for year in batch.keys():
        union = union | set(batch[year].columns)
    return union

# %%
from yaml import load

def load_aliases(file):
    with open(file) as yaml:
        aliases = load(yaml.read())
        return aliases

# %%
def alias_columns(batch, list_of_aliases):
    for year in sorted(batch.keys()):
        for column in sorted(batch[year].columns):
            if not column in list_of_aliases:
                for reference, aliases in list_of_aliases.items():
                    if aliases:
                        if column in aliases:
                            batch[year].rename(columns={column: reference}, inplace=True)
                            print(year, column, 'replaced with', reference)
                            stdout.flush()
                            break  
                else:
                    print(year, 'NO ALIAS: ', column)
                    stdout.flush()
        print('\nDone mapping', year, '\n')
        stdout.flush()

# %%
from pandas import DataFrame

def build_overview(batch):
    table = []
    
    for column in get_union_of_columns(batch):
        row = {'Column': column}
        for year in batch.keys():
            row.update({year: column in batch[year].columns})
        table.append(row)
        
    ordered_columns = ['Column']
    ordered_columns.extend(sorted(batch.keys()))
    
    overview = DataFrame(table).reindex_axis(ordered_columns, axis=1)
    return overview

# %% [markdown]
# ## Parse amount columns
#
# There's a little cleaning to do on the amount columns (zeros are represented by a dash and there is some whitespace padding). I might as well take care of this here to make sure I don't run into parsing problems later).

# %%
from numpy import nan

amounts = ['Ejercido', 'Devengado', 'Aprobado', 'Pagado', 'Modificado', 'Adefas', 'Ejercicio']

def clean_amount_columns(batch):
    for year, df in sorted(batch.items()):
        for amount in amounts:
            try:
                # Weird behaviour from pandas: although I coerced columns to strings, 
                # there are some nan values which pandas considers as floats.
                series = batch[year][amount].apply(lambda x: '' if x is nan else x)
                series = series.apply(lambda x: x.strip())
                # '-' seem to represent a zero, judging from the value counts
                series = series.apply(lambda x: '0' if x == '-' else x)
                series = series.apply(lambda x: x.replace(',', ''))
                batch[year][amount] = series
                print(year, amount, 'cleaned numerical column')
            except KeyError:
                pass

# %%
from pandas import concat

def do_pipeline(output_file):
    print('\nLoading files...\n')
    
    # Load Cuenta Publica files
    cp_years = range(2010, 2016)
    cp_file_format = 'Cuenta_Publica_%s.csv'
    detect_encoding(cp_years, cp_file_format)
    cp = load_csv_files(cp_years, cp_file_format, 'windows-1252')
    
    # Load PEF 2016
    pef_years = [2016]
    pef_file_format = 'PEF%s_AC01.csv'
    detect_encoding(pef_years, pef_file_format)
    pef = load_csv_files(pef_years, pef_file_format, 'cp850')
    
    # Assemble the two datasets in one dictionary
    datasets = cp
    datasets.update(pef)
    
    print('\nCleaning data...\n')
    strip_blanks(datasets)
    delete_empty_columns(datasets)
    
    print('\nMapping columns...\n')
    aliases = load_aliases('mexican_federal_budget_column_nomenclature.yaml')
    alias_columns(datasets, aliases)

    print('\nBuilding column overview...\n')
    overview_table = build_overview(datasets)
    
    print('\nCleaning numerical columns...\n')
    clean_amount_columns(datasets)
    
    print('\nMerging datasets...\n')
    merged_dataset = concat(list(datasets.values()))
    
    print('\nSaving to', output_file, '\n')    
    mexico.to_csv(output_file, encoding='utf-8', index=False)
    
    print('\nPipeline done!', '\n')
    return merged_dataset, overview_table

# %%
mexico, overview = do_pipeline('mexican_federal_budget.2010_to_2016.merged.csv')
# Out:
# Loading files...
#
# Inspecting Cuenta_Publica_2010.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Inspecting Cuenta_Publica_2011.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Inspecting Cuenta_Publica_2012.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Inspecting Cuenta_Publica_2013.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Inspecting Cuenta_Publica_2014.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Inspecting Cuenta_Publica_2015.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Loading Cuenta_Publica_2010.csv with encoding: windows-1252
# Loading Cuenta_Publica_2011.csv with encoding: windows-1252
# Loading Cuenta_Publica_2012.csv with encoding: windows-1252
# Loading Cuenta_Publica_2013.csv with encoding: windows-1252
# Loading Cuenta_Publica_2014.csv with encoding: windows-1252
# Loading Cuenta_Publica_2015.csv with encoding: windows-1252
# Inspecting PEF2016_AC01.csv {'encoding': 'WINDOWS-1252', 'confidence': 0.9900000095367432}
# Loading PEF2016_AC01.csv with encoding: cp850
#
# Cleaning data...
#
# 2011 Unnamed: 25 deleted
# 2011 Unnamed: 26 deleted
# 2011 Unnamed: 27 deleted
# 2011 Unnamed: 28 deleted
# 2011 Unnamed: 29 deleted
# 2011 Unnamed: 30 deleted
# 2011 Unnamed: 31 deleted
# 2011 Unnamed: 32 deleted
# 2011 Unnamed: 33 deleted
# 2011 Unnamed: 34 deleted
# 2011 Unnamed: 35 deleted
# 2011 Unnamed: 36 deleted
# 2011 Unnamed: 37 deleted
# 2011 Unnamed: 38 deleted
# 2011 Unnamed: 39 deleted
# 2011 Unnamed: 40 deleted
# 2011 Unnamed: 41 deleted
#
# Mapping columns...
#
# 2010 Descripción de Finalidad replaced with Descripción de Grupo Funcional
# 2010 Finalidad replaced with Grupo Funcional
#
# Done mapping 2010
#
# 2011 Descripción de Finalidad replaced with Descripción de Grupo Funcional
# 2011 Finalidad replaced with Grupo Funcional
#
# Done mapping 2011
#
# 2012 Descripción de Finalidad replaced with Descripción de Grupo Funcional
# 2012 Finalidad replaced with Grupo Funcional
#
# Done mapping 2012
#
# 2013 Descripción de Finalidad replaced with Descripción de Grupo Funcional
# 2013 Finalidad replaced with Grupo Funcional
#
# Done mapping 2013
#
# 2014 ADEFAS replaced with Adefas
#
# Done mapping 2014
#
#
# Done mapping 2015
#
# 2016 ACTIVIDAD_INST_DESCRIPCION replaced with Descripción de la Actividad Institucional
# 2016 AI replaced with Actividad Institucional
# 2016 CLAVE_CARTERA replaced with Clave de cartera
# 2016 CONCEPTO replaced with Objeto del Gasto
# 2016 CONCEPTO_DESCRIPCION replaced with Descripción de Objeto del Gasto
# 2016 EF replaced with Entidad Federativa
# 2016 ENTIDAD_FED_DESCRIPCION replaced with Descripción de la entidad federativa
# 2016 FF replaced with Fuente de Financiamiento
# 2016 FN replaced with Función
# 2016 FUENTE_FINAN_DESCRIPCION replaced with Descripción de Fuente de Financiamiento
# 2016 FUNCIONL_DESCRIPCION replaced with Descripción de Función
# 2016 GF replaced with Grupo Funcional
# 2016 GRUPO_FUN_DESCRIPCION replaced with Descripción de Grupo Funcional
# 2016 MOD replaced with Modalidad del Programa presupuestario
# 2016 MODALIDAD_DESCRIPCION replaced with Descripción de la modalidad del programa presupuestario
# 2016 PEF_2016 replaced with Aprobado
# 2016 PP replaced with Programa Presupuestario
# 2016 PROGR_PRES_DESCRIPCION replaced with Descripción de Programa Presupuestario
# 2016 RA replaced with Reasignacion
# 2016 RAMO_DESCRIPCION replaced with Descripción de Ramo
# 2016 REASIGNACION_DESCRIPCION replaced with Descripción de Reasignacion
# 2016 SF replaced with Subfunción
# 2016 SUBFUNCIONL_DESCRIPCION replaced with Descripción de Subfunción
# 2016 TG replaced with Tipo de Gasto
# 2016 TIPO_GASTO_DESCRIPCION replaced with Descripción de Tipo de Gasto
# 2016 UNIDAD replaced with Unidad Responsable
# 2016 UNIDAD_DESCRIPCION replaced with Descripción de Unidad Responsable
#
# Done mapping 2016
#
#
# Building column overview...
#
#
# Cleaning numerical columns...
#
# 2010 Ejercido cleaned numerical column
# 2010 Aprobado cleaned numerical column
# 2011 Ejercido cleaned numerical column
# 2011 Aprobado cleaned numerical column
# 2012 Ejercido cleaned numerical column
# 2012 Aprobado cleaned numerical column
# 2013 Ejercido cleaned numerical column
# 2013 Devengado cleaned numerical column
# 2013 Aprobado cleaned numerical column
# 2014 Devengado cleaned numerical column
# 2014 Aprobado cleaned numerical column
# 2014 Pagado cleaned numerical column
# 2014 Modificado cleaned numerical column
# 2014 Adefas cleaned numerical column
# 2014 Ejercicio cleaned numerical column
# 2015 Devengado cleaned numerical column
# 2015 Aprobado cleaned numerical column
# 2015 Pagado cleaned numerical column
# 2015 Modificado cleaned numerical column
# 2015 Adefas cleaned numerical column
# 2015 Ejercicio cleaned numerical column
# 2016 Aprobado cleaned numerical column
#
# Merging datasets...
#
#
# Saving to mexican_federal_budget.2010_to_2016.merged.csv
#
#
# Pipeline done!

# %% [markdown]
# ## Quality control

# %%
mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325512 entries, 0 to 239082
# Data columns (total 35 columns):
# Actividad Institucional                                    1325512 non-null object
# Adefas                                                     482560 non-null object
# Aprobado                                                   1325512 non-null object
# Ciclo                                                      1325512 non-null object
# Clave de cartera                                           1057671 non-null object
# Descripción de Fuente de Financiamiento                    1325511 non-null object
# Descripción de Función                                     1325512 non-null object
# Descripción de Grupo Funcional                             1325512 non-null object
# Descripción de Objeto del Gasto                            1325483 non-null object
# Descripción de Programa Presupuestario                     1325511 non-null object
# Descripción de Ramo                                        1325512 non-null object
# Descripción de Reasignacion                                75312 non-null object
# Descripción de Subfunción                                  1325512 non-null object
# Descripción de Tipo de Gasto                               1325511 non-null object
# Descripción de Unidad Responsable                          1325512 non-null object
# Descripción de la Actividad Institucional                  1325511 non-null object
# Descripción de la entidad federativa                       1057499 non-null object
# Descripción de la modalidad del programa presupuestario    1325511 non-null object
# Devengado                                                  710217 non-null object
# Ejercicio                                                  482560 non-null object
# Ejercido                                                   767640 non-null object
# Entidad Federativa                                         1057671 non-null object
# Fuente de Financiamiento                                   1325511 non-null object
# Función                                                    1325512 non-null object
# Grupo Funcional                                            1325512 non-null object
# Modalidad del Programa presupuestario                      1325511 non-null object
# Modificado                                                 482560 non-null object
# Objeto del Gasto                                           1325511 non-null object
# Pagado                                                     482560 non-null object
# Programa Presupuestario                                    1325511 non-null object
# Ramo                                                       1325512 non-null object
# Reasignacion                                               75312 non-null object
# Subfunción                                                 1325512 non-null object
# Tipo de Gasto                                              1325511 non-null object
# Unidad Responsable                                         1325512 non-null object
# dtypes: object(35)
# memory usage: 364.1+ MB

# %%
mexico.sample(n=20)
# Out:
#        Actividad Institucional Adefas      Aprobado Ciclo Clave de cartera  \
# 84565                        7    NaN       58434.0  2013                0
# 127579                       2    NaN         33461  2012                0
# 29850                        2    NaN      121678.0  2010              NaN
# 138361                       5      0          4297  2014               0
# 151305                       3    NaN             0  2013      1216B000109
# 236209                       1    NaN         11838  2012                0
# 31488                        5    NaN             0  2011              NaN
# 13180                        6    NaN        550271  2012                0
# 23435                       23    NaN         45000  2012                0
# 59734                       10    NaN        713000  2011              NaN
# 180915                       3    NaN       10389.0  2013                0
# 76398                       10   0.00        420.00  2015      10096400004
# 42292                        8    NaN       2193508  2016                0
# 63415                       10    NaN          1600  2012       7096320005
# 192277                       8   0.00          0.00  2015                0
# 178332                       4      0         82933  2014               0
# 96117                       10    NaN        8656.0  2013                0
# 143786                       5   0.00       6000.00  2015                0
# 143252                       4   4640          3452  2014               0
# 196318                       3   0.00  199123731.00  2015                0
#
#        Descripción de Fuente de Financiamiento  \
# 84565                        Recursos fiscales
# 127579                       Recursos fiscales
# 29850                        Recursos fiscales
# 138361                       Recursos fiscales
# 151305                       Recursos fiscales
# 236209                       Recursos fiscales
# 31488                        Recursos fiscales
# 13180                        Recursos fiscales
# 23435                        Recursos fiscales
# 59734                        Recursos fiscales
# 180915                       Recursos fiscales
# 76398                        Recursos fiscales
# 42292                        Recursos fiscales
# 63415                        Recursos fiscales
# 192277                       Recursos fiscales
# 178332                       Recursos fiscales
# 96117                        Recursos fiscales
# 143786                       Recursos fiscales
# 143252                       Recursos fiscales
# 196318                       Recursos fiscales
#
#                                    Descripción de Función  \
# 84565                                      Comunicaciones
# 127579                                          Educación
# 29850                        Comunicaciones y Transportes
# 138361  Asuntos Económicos, Comerciales y Laborales en...
# 151305           Agropecuaria, Silvicultura, Pesca y Caza
# 236209            Coordinación de la Política de Gobierno
# 31488                        Comunicaciones y Transportes
# 13180             Coordinación de la Política de Gobierno
# 23435                                            Justicia
# 59734                                           Educación
# 180915                                           Justicia
# 76398                                          Transporte
# 42292                                   Protección Social
# 63415                                          Transporte
# 192277                                  Protección Social
# 178332                             Combustibles y Energía
# 96117                                           Educación
# 143786  Asuntos Económicos, Comerciales y Laborales en...
# 143252           Agropecuaria, Silvicultura, Pesca y Caza
# 196318                                          Educación
#
#        Descripción de Grupo Funcional  \
# 84565            Desarrollo Económico
# 127579              Desarrollo Social
# 29850            Desarrollo Económico
# 138361           Desarrollo Económico
# 151305           Desarrollo Económico
# 236209                       Gobierno
# 31488            Desarrollo Económico
# 13180                        Gobierno
# 23435                        Gobierno
# 59734               Desarrollo Social
# 180915                       Gobierno
# 76398            Desarrollo Económico
# 42292               Desarrollo Social
# 63415            Desarrollo Económico
# 192277              Desarrollo Social
# 178332           Desarrollo Económico
# 96117               Desarrollo Social
# 143786           Desarrollo Económico
# 143252           Desarrollo Económico
# 196318              Desarrollo Social
#
#                           Descripción de Objeto del Gasto  \
# 84565                         Otros servicios comerciales
# 127579                     Funerales y pagas de defunción
# 29850           Mantenimiento y conservación de inmuebles
# 138361                   Material eléctrico y electrónico
# 151305  Información en medios masivos derivada de la o...
# 236209  Refacciones y accesorios menores de equipo de ...
# 31488         Servicios de lavandería, limpieza e higiene
# 13180                    Servicio telefónico convencional
# 23435   Pasajes terrestres nacionales para labores en ...
# 59734                                Material de limpieza
# 180915  Refacciones y accesorios para equipo de cómput...
# 76398                    Material eléctrico y electrónico
# 42292                                    Seguridad social
# 63415                         Otros servicios comerciales
# 192277      Refacciones y accesorios menores de edificios
# 178332                          Aportaciones al FOVISSSTE
# 96117   Cuotas para el seguro de gastos médicos del pe...
# 143786    Materiales y útiles de impresión y reproducción
# 143252                                   Servicio de agua
# 196318  Aportaciones federales a las entidades federat...
#
#                    Descripción de Programa Presupuestario        ...          \
# 84565                                 Servicios de correo        ...
# 127579                Actividades de apoyo administrativo        ...
# 29850                 Actividades de apoyo administrativo        ...
# 138361  Ejecución a nivel nacional de los programas y ...        ...
# 151305             Estabilización de cuencas y acuíferos.        ...
# 236209  Capacitar y educar para el ejercicio democráti...        ...
# 31488   Supervisión, inspección y verificación del tra...        ...
# 13180   Conducción de la política interior y las relac...        ...
# 23435   Atención Integral a Familiares de Personas Des...        ...
# 59734                     Normar los servicios educativos        ...
# 180915  Resolución de asuntos relativos a conflictos y...        ...
# 76398   Proyectos de infraestructura económica de carr...        ...
# 42292   Promoción y evaluación de la política de desar...        ...
# 63415   Proyectos de infraestructura económica de carr...        ...
# 192277              PROSPERA Programa de Inclusión Social        ...
# 178332  Regulación de la exploración y extracción de h...        ...
# 96117        Diseño y aplicación de la política educativa        ...
# 143786  Ejecución a nivel nacional de los programas y ...        ...
# 143252  Implementación de políticas enfocadas al medio...        ...
# 196318                      FONE Otros de Gasto Corriente        ...
#
#        Modalidad del Programa presupuestario    Modificado Objeto del Gasto  \
# 84565                                      E           NaN            33602
# 127579                                     M           NaN            39101
# 29850                                      M           NaN             3504
# 138361                                     E         10848            24601
# 151305                                     K           NaN            33605
# 236209                                     R           NaN            29601
# 31488                                      G           NaN            35801
# 13180                                      P           NaN            31401
# 23435                                      E           NaN            37201
# 59734                                      G           NaN            21601
# 180915                                     E           NaN            29401
# 76398                                      K        382.21            24601
# 42292                                      P           NaN             1400
# 63415                                      K           NaN            33602
# 192277                                     S          0.00            29201
# 178332                                     G         94675            14201
# 96117                                      P           NaN            14403
# 143786                                     E          0.00            21201
# 143252                                     P         26056            31301
# 196318                                     I  199123731.00            83103
#
#               Pagado Programa Presupuestario Ramo Reasignacion Subfunción  \
# 84565            NaN                      12    9          NaN          1
# 127579           NaN                       1   11          NaN          6
# 29850            NaN                       1    9          NaN          6
# 138361         10848                       3   14          NaN          2
# 151305           NaN                     141   16          NaN          5
# 236209           NaN                       3   22          NaN          6
# 31488            NaN                       2    9          NaN          3
# 13180            NaN                       1    4          NaN          2
# 23435            NaN                      34    6          NaN          4
# 59734            NaN                       1   11          NaN          8
# 180915           NaN                       1   31          NaN          1
# 76398         382.21                      31    9          NaN          1
# 42292            NaN                       2   20            0          8
# 63415            NaN                      31    9          NaN          1
# 192277          0.00                      72   20          NaN          8
# 178332         94675                       4   18          NaN          2
# 96117            NaN                       1   11          NaN          6
# 143786          0.00                       3   14          NaN          2
# 143252         21416                       1   15          NaN          1
# 196318  199123731.00                      14   33          NaN          1
#
#        Tipo de Gasto Unidad Responsable
# 84565              1                J9E
# 127579             1                712
# 29850              1                630
# 138361             1                125
# 151305             3                B00
# 236209             1                300
# 31488              1                626
# 13180              1                213
# 23435              1                AYJ
# 59734              1                311
# 180915             1                200
# 76398              3                640
# 42292              1                150
# 63415              3                632
# 192277             7                G00
# 178332             1                D00
# 96117              1                121
# 143786             1                133
# 143252             1                122
# 196318             1                416
#
# [20 rows x 35 columns]

# %%
overview
# Out:
#                                                Column   2010   2011   2012  \
# 0   Descripción de la modalidad del programa presu...   True   True   True
# 1                           Descripción de Subfunción   True   True   True
# 2                                    Clave de cartera  False  False   True
# 3                                     Grupo Funcional   True   True   True
# 4                             Actividad Institucional   True   True   True
# 5             Descripción de Fuente de Financiamiento   True   True   True
# 6                                           Devengado  False  False  False
# 7                   Descripción de Unidad Responsable   True   True   True
# 8                                          Modificado  False  False  False
# 9                                                Ramo   True   True   True
# 10                       Descripción de Tipo de Gasto   True   True   True
# 11               Descripción de la entidad federativa  False  False   True
# 12                     Descripción de Grupo Funcional   True   True   True
# 13                                            Función   True   True   True
# 14                                       Reasignacion  False  False  False
# 15                            Programa Presupuestario   True   True   True
# 16                                   Objeto del Gasto   True   True   True
# 17              Modalidad del Programa presupuestario   True   True   True
# 18                                 Unidad Responsable   True   True   True
# 19                                 Entidad Federativa  False  False   True
# 20             Descripción de Programa Presupuestario   True   True   True
# 21                    Descripción de Objeto del Gasto   True   True   True
# 22          Descripción de la Actividad Institucional   True   True   True
# 23                                              Ciclo   True   True   True
# 24                           Fuente de Financiamiento   True   True   True
# 25                                         Subfunción   True   True   True
# 26                        Descripción de Reasignacion  False  False  False
# 27                                      Tipo de Gasto   True   True   True
# 28                                Descripción de Ramo   True   True   True
# 29                                           Aprobado   True   True   True
# 30                                             Pagado  False  False  False
# 31                                             Adefas  False  False  False
# 32                             Descripción de Función   True   True   True
# 33                                           Ejercido   True   True   True
# 34                                          Ejercicio  False  False  False
#
#      2013   2014   2015   2016
# 0    True   True   True   True
# 1    True   True   True   True
# 2    True   True   True   True
# 3    True   True   True   True
# 4    True   True   True   True
# 5    True   True   True   True
# 6    True   True   True  False
# 7    True   True   True   True
# 8   False   True   True  False
# 9    True   True   True   True
# 10   True   True   True   True
# 11   True   True   True   True
# 12   True   True   True   True
# 13   True   True   True   True
# 14  False  False  False   True
# 15   True   True   True   True
# 16   True   True   True   True
# 17   True   True   True   True
# 18   True   True   True   True
# 19   True   True   True   True
# 20   True   True   True   True
# 21   True   True   True   True
# 22   True   True   True   True
# 23   True   True   True   True
# 24   True   True   True   True
# 25   True   True   True   True
# 26  False  False  False   True
# 27   True   True   True   True
# 28   True   True   True   True
# 29   True   True   True   True
# 30  False   True   True  False
# 31  False   True   True  False
# 32   True   True   True   True
# 33   True  False  False  False
# 34  False   True   True  False

# %%
ls -lh | grep mexican_federal_budget.2010_to_2016
# Out:
# -rw-rw-r-- 1 loic loic 610M Aug  9 17:58 mexican_federal_budget.2010_to_2016.merged.csv

# %%
cat mexican_federal_budget.2010_to_2016.merged.csv | head -n 10
# Out:
# Actividad Institucional,Adefas,Aprobado,Ciclo,Clave de cartera,Descripción de Fuente de Financiamiento,Descripción de Función,Descripción de Grupo Funcional,Descripción de Objeto del Gasto,Descripción de Programa Presupuestario,Descripción de Ramo,Descripción de Reasignacion,Descripción de Subfunción,Descripción de Tipo de Gasto,Descripción de Unidad Responsable,Descripción de la Actividad Institucional,Descripción de la entidad federativa,Descripción de la modalidad del programa presupuestario,Devengado,Ejercicio,Ejercido,Entidad Federativa,Fuente de Financiamiento,Función,Grupo Funcional,Modalidad del Programa presupuestario,Modificado,Objeto del Gasto,Pagado,Programa Presupuestario,Ramo,Reasignacion,Subfunción,Tipo de Gasto,Unidad Responsable
# 4,,99305000,2016,0,Recursos fiscales,Legislación,Gobierno,Obra pública en bienes propios,Mantenimiento de Infraestructura,Poder Legislativo,Otros,Legislación,Gasto de obra pública,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Proyectos de Inversión,,,,9,1,1,1,K,,6200,,27,1,0,1,3,100
# 4,,1003938481,2016,0,Recursos fiscales,Legislación,Gobierno,Remuneraciones al personal de carácter permanente,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,1100,,1,1,0,1,1,100
# 4,,965197125,2016,0,Recursos fiscales,Legislación,Gobierno,Remuneraciones al personal de carácter transitorio,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,1200,,1,1,0,1,1,100
# 4,,1024814700,2016,0,Recursos fiscales,Legislación,Gobierno,Remuneraciones adicionales y especiales,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,1300,,1,1,0,1,1,100
# 4,,381460621,2016,0,Recursos fiscales,Legislación,Gobierno,Seguridad social,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,1400,,1,1,0,1,1,100
# 4,,955361812,2016,0,Recursos fiscales,Legislación,Gobierno,Otras prestaciones sociales y económicas,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,1500,,1,1,0,1,1,100
# 4,,139834278,2016,0,Recursos fiscales,Legislación,Gobierno,Pago de estímulos a servidores públicos,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,1700,,1,1,0,1,1,100
# 4,,50923657,2016,0,Recursos fiscales,Legislación,Gobierno,"Materiales de administración, emisión de documentos y artículos oficiales",Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,2100,,1,1,0,1,1,100
# 4,,57107585,2016,0,Recursos fiscales,Legislación,Gobierno,Alimentos y utensilios,Actividades derivadas del trabajo legislativo,Poder Legislativo,Otros,Legislación,Gasto corriente,H. Cámara de Diputados,Llevar a cabo el proceso Legislativo,Distrito Federal,Específicos,,,,9,1,1,1,R,,2200,,1,1,0,1,1,100
# cat: write error: Broken pipe
